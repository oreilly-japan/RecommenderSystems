# %% [markdown]
# # Factorization Machiens

# %%
# 親のフォルダのパスを追加
import sys; sys.path.insert(0, '..')

from util.data_loader import DataLoader
from util.metric_calculator import MetricCalculator

# %%
# Movielensのデータの読み込み
data_loader = DataLoader(num_users=1000, num_test_items=5, data_path='../data/ml-10M100K/')
movielens = data_loader.load()

# %%
# FMレコメンド
from src.fm import FMRecommender
recommender = FMRecommender()
recommend_result = recommender.recommend(movielens)
# Out:
# ----------------------------------------------------------------------------------------------
#            _
#           | |
#      __  _| |     ___  __ _ _ __ _ __
#      \ \/ / |    / _ \/ _` | '__| '_ \
#       >  <| |___|  __/ (_| | |  | | | |
#      /_/\_\_____/\___|\__,_|_|  |_| |_|
#
#         xLearn   -- 0.40 Version --
# ----------------------------------------------------------------------------------------------
#
# [ WARNING    ] Validation file not found, xLearn has already disable early-stopping.
# [ WARNING    ] Validation file not found, xLearn has already disable (-x rmse) option.
# [------------] xLearn uses 4 threads for training task.
# [ ACTION     ] Read Problem ...
# [------------] First check if the text file has been already converted to binary format.
# [------------] Binary file (/var/folders/31/92gcylk93xvbjbyb75sdmpqm0000gn/T/tmpj010yd3q.bin) NOT found. Convert text file to binary file.
# [------------] Number of Feature: 1061
# [------------] Time cost for reading problem: 0.02 (sec)
# [ ACTION     ] Initialize model ...
# [------------] Model size: 53.89 KB
# [------------] Time cost for model initial: 0.00 (sec)
# [ ACTION     ] Start to train ...
# [------------] Epoch      Train mse_loss     Time cost (sec)
# [    2%      ]     1            0.454755                0.01
# [    4%      ]     2            0.393448                0.01
# [    6%      ]     3            0.377439                0.01
# [    8%      ]     4            0.368265                0.01
# [   10%      ]     5            0.361691                0.01
# [   12%      ]     6            0.357060                0.01
# [   14%      ]     7            0.353435                0.01
# [   16%      ]     8            0.350939                0.01
# [   18%      ]     9            0.349071                0.01
# [   20%      ]    10            0.347328                0.01
# [   22%      ]    11            0.346160                0.01
# [   24%      ]    12            0.344894                0.01
# [   26%      ]    13            0.344078                0.01
# [   28%      ]    14            0.343410                0.00
# [   30%      ]    15            0.342319                0.00
# [   32%      ]    16            0.342305                0.00
# [   34%      ]    17            0.341846                0.01
# [   36%      ]    18            0.341080                0.01
# [   38%      ]    19            0.340690                0.01
# [   40%      ]    20            0.340196                0.01
# [   42%      ]    21            0.340085                0.01
# [   44%      ]    22            0.339978                0.01
# [   46%      ]    23            0.340111                0.01
# [   48%      ]    24            0.339314                0.00
# [   50%      ]    25            0.339661                0.00
# [   52%      ]    26            0.338927                0.01
# [   54%      ]    27            0.338808                0.01
# [   56%      ]    28            0.338580                0.01
# [   57%      ]    29            0.338881                0.00
# [   60%      ]    30            0.338765                0.01
# [   62%      ]    31            0.338443                0.01
# [   64%      ]    32            0.338499                0.01
# [   66%      ]    33            0.338384                0.01
# [   68%      ]    34            0.337989                0.01
# [   70%      ]    35            0.337732                0.01
# [   72%      ]    36            0.337837                0.01
# [   74%      ]    37            0.338007                0.00
# [   76%      ]    38            0.337921                0.00
# [   78%      ]    39            0.337922                0.01
# [   80%      ]    40            0.337580                0.00
# [   82%      ]    41            0.337862                0.00
# [   84%      ]    42            0.337982                0.01
# [   86%      ]    43            0.336908                0.01
# [   88%      ]    44            0.337312                0.01
# [   90%      ]    45            0.337479                0.00
# [   92%      ]    46            0.337478                0.01
# [   94%      ]    47            0.337445                0.01
# [   96%      ]    48            0.337600                0.01
# [   98%      ]    49            0.337286                0.01
# [  100%      ]    50            0.337232                0.01
# [ ACTION     ] Start to save model ...
# [------------] Model file: /var/folders/31/92gcylk93xvbjbyb75sdmpqm0000gn/T/tmpxh6ei75k
# [------------] Time cost for saving model: 0.00 (sec)
# [ ACTION     ] Start to save txt model ...
# [------------] TXT Model file: /var/folders/31/92gcylk93xvbjbyb75sdmpqm0000gn/T/tmprefexgam
# [------------] Time cost for saving txt model: 0.00 (sec)
# [ ACTION     ] Finish training
# [ ACTION     ] Clear the xLearn environment ...
# [------------] Total time cost: 0.34 (sec)
# ----------------------------------------------------------------------------------------------
#            _
#           | |
#      __  _| |     ___  __ _ _ __ _ __
#      \ \/ / |    / _ \/ _` | '__| '_ \
#       >  <| |___|  __/ (_| | |  | | | |
#      /_/\_\_____/\___|\__,_|_|  |_| |_|
#
#         xLearn   -- 0.40 Version --
# ----------------------------------------------------------------------------------------------
#
# [------------] xLearn uses 8 threads for prediction task.
# [ ACTION     ] Load model ...
# [------------] Load model from /var/folders/31/92gcylk93xvbjbyb75sdmpqm0000gn/T/tmpxh6ei75k
# [------------] Loss function: squared
# [------------] Score function: fm
# [------------] Number of Feature: 1061
# [------------] Number of K: 10
# [------------] Time cost for loading model: 0.00 (sec)
# [ ACTION     ] Read Problem ...
# [------------] First check if the text file has been already converted to binary format.
# [------------] Binary file (/var/folders/31/92gcylk93xvbjbyb75sdmpqm0000gn/T/tmpr2wl3i7s.bin) NOT found. Convert text file to binary file.
# [------------] Time cost for reading problem: 0.04 (sec)
# [ ACTION     ] Start to predict ...
# [------------] The test loss is: 6.944547
# [ ACTION     ] Clear the xLearn environment ...
# [------------] Total time cost: 0.07 (sec)

# %%
#  評価
metric_calculator = MetricCalculator()
metrics = metric_calculator.calc(
    movielens.test.rating.tolist(), recommend_result.rating.tolist(),
    movielens.test_user2items, recommend_result.user2items, k=10)
print(metrics)
# Out:
# rmse=1.054, Precision@K=0.013, Recall@K=0.040

# %%
# 補助情報の利用
recommend_result = recommender.recommend(movielens, use_side_information=True)
metrics = metric_calculator.calc(
movielens.test.rating.tolist(), recommend_result.rating.tolist(),
movielens.test_user2items, recommend_result.user2items, k=10)
print(metrics)
# Out:
# ----------------------------------------------------------------------------------------------
#            _
#           | |
#      __  _| |     ___  __ _ _ __ _ __
#      \ \/ / |    / _ \/ _` | '__| '_ \
#       >  <| |___|  __/ (_| | |  | | | |
#      /_/\_\_____/\___|\__,_|_|  |_| |_|
#
#         xLearn   -- 0.40 Version --
# ----------------------------------------------------------------------------------------------
#
# [ WARNING    ] Validation file not found, xLearn has already disable early-stopping.
# [ WARNING    ] Validation file not found, xLearn has already disable (-x rmse) option.
# [------------] xLearn uses 4 threads for training task.
# [ ACTION     ] Read Problem ...
# [------------] First check if the text file has been already converted to binary format.
# [------------] Binary file (/var/folders/31/92gcylk93xvbjbyb75sdmpqm0000gn/T/tmpmoz52pqt.bin) NOT found. Convert text file to binary file.
# [------------] Number of Feature: 3050
# [------------] Time cost for reading problem: 0.20 (sec)
# [ ACTION     ] Initialize model ...
# [------------] Model size: 154.89 KB
# [------------] Time cost for model initial: 0.00 (sec)
# [ ACTION     ] Start to train ...
# [------------] Epoch      Train mse_loss     Time cost (sec)
# [    2%      ]     1            0.513912                0.03
# [    4%      ]     2            0.505483                0.03
# [    6%      ]     3            0.505344                0.03
# [    8%      ]     4            0.505056                0.03
# [   10%      ]     5            0.504832                0.03
# [   12%      ]     6            0.504601                0.03
# [   14%      ]     7            0.504817                0.03
# [   16%      ]     8            0.504538                0.03
# [   18%      ]     9            0.504791                0.03
# [   20%      ]    10            0.504338                0.03
# [   22%      ]    11            0.504382                0.03
# [   24%      ]    12            0.504559                0.04
# [   26%      ]    13            0.504786                0.03
# [   28%      ]    14            0.504537                0.03
# [   30%      ]    15            0.504704                0.03
# [   32%      ]    16            0.504768                0.03
# [   34%      ]    17            0.505108                0.03
# [   36%      ]    18            0.504066                0.04
# [   38%      ]    19            0.504696                0.04
# [   40%      ]    20            0.504488                0.04
# [   42%      ]    21            0.504811                0.04
# [   44%      ]    22            0.504666                0.04
# [   46%      ]    23            0.505006                0.04
# [   48%      ]    24            0.504503                0.03
# [   50%      ]    25            0.504566                0.03
# [   52%      ]    26            0.504758                0.03
# [   54%      ]    27            0.505005                0.03
# [   56%      ]    28            0.504476                0.03
# [   57%      ]    29            0.505133                0.03
# [   60%      ]    30            0.505088                0.03
# [   62%      ]    31            0.504721                0.03
# [   64%      ]    32            0.505171                0.03
# [   66%      ]    33            0.504432                0.03
# [   68%      ]    34            0.504932                0.03
# [   70%      ]    35            0.504518                0.03
# [   72%      ]    36            0.504382                0.03
# [   74%      ]    37            0.504451                0.03
# [   76%      ]    38            0.505267                0.03
# [   78%      ]    39            0.504785                0.03
# [   80%      ]    40            0.504652                0.03
# [   82%      ]    41            0.505083                0.03
# [   84%      ]    42            0.504539                0.03
# [   86%      ]    43            0.504432                0.03
# [   88%      ]    44            0.504587                0.03
# [   90%      ]    45            0.504894                0.03
# [   92%      ]    46            0.504842                0.03
# [   94%      ]    47            0.504761                0.03
# [   96%      ]    48            0.504826                0.03
# [   98%      ]    49            0.504952                0.03
# [  100%      ]    50            0.504972                0.03
# [ ACTION     ] Start to save model ...
# [------------] Model file: /var/folders/31/92gcylk93xvbjbyb75sdmpqm0000gn/T/tmpgccvgagg
# [------------] Time cost for saving model: 0.00 (sec)
# [ ACTION     ] Start to save txt model ...
# [------------] TXT Model file: /var/folders/31/92gcylk93xvbjbyb75sdmpqm0000gn/T/tmpzy7o5uqs
# [------------] Time cost for saving txt model: 0.01 (sec)
# [ ACTION     ] Finish training
# [ ACTION     ] Clear the xLearn environment ...
# [------------] Total time cost: 1.86 (sec)
# ----------------------------------------------------------------------------------------------
#            _
#           | |
#      __  _| |     ___  __ _ _ __ _ __
#      \ \/ / |    / _ \/ _` | '__| '_ \
#       >  <| |___|  __/ (_| | |  | | | |
#      /_/\_\_____/\___|\__,_|_|  |_| |_|
#
#         xLearn   -- 0.40 Version --
# ----------------------------------------------------------------------------------------------
#
# [------------] xLearn uses 8 threads for prediction task.
# [ ACTION     ] Load model ...
# [------------] Load model from /var/folders/31/92gcylk93xvbjbyb75sdmpqm0000gn/T/tmpgccvgagg
# [------------] Loss function: squared
# [------------] Score function: fm
# [------------] Number of Feature: 3050
# [------------] Number of K: 10
# [------------] Time cost for loading model: 0.00 (sec)
# [ ACTION     ] Read Problem ...
# [------------] First check if the text file has been already converted to binary format.
# [------------] Binary file (/var/folders/31/92gcylk93xvbjbyb75sdmpqm0000gn/T/tmpegzkkg74.bin) NOT found. Convert text file to binary file.
# [------------] Time cost for reading problem: 0.55 (sec)
# [ ACTION     ] Start to predict ...
# [------------] The test loss is: 7.458863
# [ ACTION     ] Clear the xLearn environment ...
# [------------] Total time cost: 0.60 (sec)
# rmse=1.068, Precision@K=0.015, Recall@K=0.050
